# %%
# !brew search wxtools
# Out:
# ==> Formulae
# lwtools    wcstools   swftools   pwntools   hcxtools   mtools     dtools
#
# ==> Casks
# utools

# %%
import os, sys
import wxWidgets
import wxWidgets.lib
import wxWidgets.lib.ogl as ogl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 2
#       1 import os, sys
# ----> 2 import wxWidgets
#       3 import wxWidgets.lib
#       4 import wxWidgets.lib.ogl as ogl
#
# ModuleNotFoundError: No module named 'wxWidgets'

# %%
try:
    from wx.lib.wordwrap import wordwrap
except ImportError:
    wordwrap = lambda text, width, dc: text

try:
    from template import Template
except ImportError:
    # we are frozen?
    from fpdf.template import Template
